# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import csv

def load_csv(filepath):
    with open(filepath, newline='') as csvfile:
        return list(csv.DictReader(csvfile))

# %%
import simplejson

def json_load(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        return simplejson.load(f)

def json_save(data, filename):
    with open(filename, 'w', encoding='utf-8') as f:
        simplejson.dump(data, f, separators=(',', ':'), iterable_as_array=True)

# %%
csv_file_path = '../data/BBairline200722_coreffed.csv'
csv_data = load_csv(csv_file_path)

# %%
single_quote_unicode = ord("'")
translation_table_text = str.maketrans(
    {
        '`': single_quote_unicode,
        '‘': single_quote_unicode,
        '’': single_quote_unicode,
        '“': single_quote_unicode,
        '”': single_quote_unicode,
    }
)
     
corpus_texts_full, corpus_titles_full = [], []
for row in csv_data:
    text, title = row['text'].translate(translation_table_text), row['title']
    corpus_texts_full.append(text)
    corpus_titles_full.append(title)

# %%
def get_ents_ids(ents):
    ent_ids = []
    processing_ent = False
    for idx, (word, tag) in enumerate(ents):
        if tag != 'O':
            pos, ent_type = tag.split('-')
        else:
            pos = None
        if not processing_ent:
            if pos:
                ent_ids.append([idx])
                if pos == 'B':
                    processing_ent = True
        else:
            ent_ids[-1].append(idx)
            if pos == 'L':
                processing_ent = False
    return ent_ids

# %%
# %%time
from allennlp.predictors import Predictor
predictor_models = ('ner-model-2020.02.10', 'fine-grained-ner.2021-02-11', 'fgner-transformer.2021-02-11',)
predictors = {m: Predictor.from_path(f"https://storage.googleapis.com/allennlp-public-models/{m}.tar.gz") for m in predictor_models}
# Out:
# 2021-09-25 20:04:41.813373: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-09-25 20:04:41.813404: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/dnk8n/miniconda3/envs/internship/lib/python3.8/site-packages/allennlp/tango/__init__.py:17: UserWarning: AllenNLP Tango is an experimental API and parts of it might change or disappear every time we release a new version.
#   warnings.warn(
# 2021-09-25 20:04:46,186 : INFO : NumExpr defaulting to 4 threads.
# 2021-09-25 20:04:46,902 : INFO : Plugin allennlp_models available
# 2021-09-25 20:04:47,320 : INFO : cache of https://storage.googleapis.com/allennlp-public-models/ner-model-2020.02.10.tar.gz is up-to-date
# 2021-09-25 20:04:47,321 : INFO : loading archive file https://storage.googleapis.com/allennlp-public-models/ner-model-2020.02.10.tar.gz from cache at /home/dnk8n/.allennlp/cache/298798bbebac87143a3b421ff478cca929a5e43926e19f879c053473827e55c6.dad72088b0fc59006a39cb50270a64476d176006a3054327423c35096d8c4265
# 2021-09-25 20:04:47,322 : INFO : extracting archive file /home/dnk8n/.allennlp/cache/298798bbebac87143a3b421ff478cca929a5e43926e19f879c053473827e55c6.dad72088b0fc59006a39cb50270a64476d176006a3054327423c35096d8c4265 to temp dir /tmp/tmpk6qw2vlh
# 2021-09-25 20:04:52,919 : INFO : dataset_reader.type = conll2003
# 2021-09-25 20:04:52,920 : INFO : dataset_reader.max_instances = None
# 2021-09-25 20:04:52,921 : INFO : dataset_reader.manual_distributed_sharding = False
# 2021-09-25 20:04:52,922 : INFO : dataset_reader.manual_multiprocess_sharding = False
# 2021-09-25 20:04:52,923 : INFO : dataset_reader.token_indexers.type = ref
# 2021-09-25 20:04:52,926 : INFO : dataset_reader.token_indexers.elmo.type = elmo_characters
# 2021-09-25 20:04:52,927 : INFO : dataset_reader.token_indexers.elmo.type = elmo_characters
# 2021-09-25 20:04:52,928 : INFO : dataset_reader.token_indexers.elmo.namespace = elmo_characters
# 2021-09-25 20:04:52,929 : INFO : dataset_reader.token_indexers.elmo.tokens_to_add = None
# 2021-09-25 20:04:52,930 : INFO : dataset_reader.token_indexers.elmo.token_min_padding_length = 0
# 2021-09-25 20:04:52,938 : INFO : dataset_reader.token_indexers.token_characters.type = characters
# 2021-09-25 20:04:52,944 : INFO : dataset_reader.token_indexers.token_characters.type = characters
# 2021-09-25 20:04:52,947 : INFO : dataset_reader.token_indexers.token_characters.namespace = token_characters
# 2021-09-25 20:04:52,954 : INFO : dataset_reader.token_indexers.token_characters.character_tokenizer = <allennlp.data.tokenizers.character_tokenizer.CharacterTokenizer object at 0x7f63ca44e760>
# 2021-09-25 20:04:52,956 : INFO : dataset_reader.token_indexers.token_characters.start_tokens = None
# 2021-09-25 20:04:52,958 : INFO : dataset_reader.token_indexers.token_characters.end_tokens = None
# 2021-09-25 20:04:52,959 : INFO : dataset_reader.token_indexers.token_characters.min_padding_length = 0
# 2021-09-25 20:04:52,961 : INFO : dataset_reader.token_indexers.token_characters.token_min_padding_length = 0
# /home/dnk8n/miniconda3/envs/internship/lib/python3.8/site-packages/allennlp/data/token_indexers/token_characters_indexer.py:55: UserWarning: You are using the default value (0) of `min_padding_length`, which can cause some subtle bugs (more info see https://github.com/allenai/allennlp/issues/1954). Strongly recommend to set a value, usually the maximum size of the convolutional layer size when using CnnEncoder.
#   warnings.warn(
# 2021-09-25 20:04:52,964 : INFO : dataset_reader.token_indexers.tokens.type = single_id
# 2021-09-25 20:04:52,965 : INFO : dataset_reader.token_indexers.tokens.type = single_id
# 2021-09-25 20:04:52,970 : INFO : dataset_reader.token_indexers.tokens.namespace = tokens
# 2021-09-25 20:04:52,971 : INFO : dataset_reader.token_indexers.tokens.lowercase_tokens = True
# 2021-09-25 20:04:52,979 : INFO : dataset_reader.token_indexers.tokens.start_tokens = None
# 2021-09-25 20:04:52,981 : INFO : dataset_reader.token_indexers.tokens.end_tokens = None
# 2021-09-25 20:04:52,984 : INFO : dataset_reader.token_indexers.tokens.feature_name = text
# 2021-09-25 20:04:52,986 : INFO : dataset_reader.token_indexers.tokens.default_value = THIS IS A REALLY UNLIKELY VALUE THAT HAS TO BE A STRING
# 2021-09-25 20:04:52,987 : INFO : dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2021-09-25 20:04:52,988 : INFO : dataset_reader.tag_label = ner
# 2021-09-25 20:04:52,991 : INFO : type = ner
# 2021-09-25 20:04:52,996 : INFO : dataset_reader.feature_labels = ()
# 2021-09-25 20:04:52,999 : INFO : dataset_reader.convert_to_coding_scheme = None
# 2021-09-25 20:04:53,001 : INFO : dataset_reader.label_namespace = labels
# 2021-09-25 20:04:53,004 : INFO : dataset_reader.type = conll2003
# 2021-09-25 20:04:53,005 : INFO : dataset_reader.max_instances = None
# 2021-09-25 20:04:53,007 : INFO : dataset_reader.manual_distributed_sharding = False
# 2021-09-25 20:04:53,009 : INFO : dataset_reader.manual_multiprocess_sharding = False
# 2021-09-25 20:04:53,011 : INFO : dataset_reader.token_indexers.type = ref
# 2021-09-25 20:04:53,015 : INFO : dataset_reader.token_indexers.elmo.type = elmo_characters
# 2021-09-25 20:04:53,018 : INFO : dataset_reader.token_indexers.elmo.type = elmo_characters
# 2021-09-25 20:04:53,021 : INFO : dataset_reader.token_indexers.elmo.namespace = elmo_characters
# 2021-09-25 20:04:53,022 : INFO : dataset_reader.token_indexers.elmo.tokens_to_add = None
# 2021-09-25 20:04:53,025 : INFO : dataset_reader.token_indexers.elmo.token_min_padding_length = 0
# 2021-09-25 20:04:53,026 : INFO : dataset_reader.token_indexers.token_characters.type = characters
# 2021-09-25 20:04:53,027 : INFO : dataset_reader.token_indexers.token_characters.type = characters
# 2021-09-25 20:04:53,029 : INFO : dataset_reader.token_indexers.token_characters.namespace = token_characters
# 2021-09-25 20:04:53,030 : INFO : dataset_reader.token_indexers.token_characters.character_tokenizer = <allennlp.data.tokenizers.character_tokenizer.CharacterTokenizer object at 0x7f63ca44e760>
# 2021-09-25 20:04:53,031 : INFO : dataset_reader.token_indexers.token_characters.start_tokens = None
# 2021-09-25 20:04:53,032 : INFO : dataset_reader.token_indexers.token_characters.end_tokens = None
# 2021-09-25 20:04:53,033 : INFO : dataset_reader.token_indexers.token_characters.min_padding_length = 0
# 2021-09-25 20:04:53,034 : INFO : dataset_reader.token_indexers.token_characters.token_min_padding_length = 0
# 2021-09-25 20:04:53,035 : INFO : dataset_reader.token_indexers.tokens.type = single_id
# 2021-09-25 20:04:53,036 : INFO : dataset_reader.token_indexers.tokens.type = single_id
# 2021-09-25 20:04:53,037 : INFO : dataset_reader.token_indexers.tokens.namespace = tokens
# 2021-09-25 20:04:53,038 : INFO : dataset_reader.token_indexers.tokens.lowercase_tokens = True
# 2021-09-25 20:04:53,039 : INFO : dataset_reader.token_indexers.tokens.start_tokens = None
# 2021-09-25 20:04:53,040 : INFO : dataset_reader.token_indexers.tokens.end_tokens = None
# 2021-09-25 20:04:53,047 : INFO : dataset_reader.token_indexers.tokens.feature_name = text
# 2021-09-25 20:04:53,048 : INFO : dataset_reader.token_indexers.tokens.default_value = THIS IS A REALLY UNLIKELY VALUE THAT HAS TO BE A STRING
# 2021-09-25 20:04:53,049 : INFO : dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2021-09-25 20:04:53,050 : INFO : dataset_reader.tag_label = ner
# 2021-09-25 20:04:53,051 : INFO : type = ner
# 2021-09-25 20:04:53,052 : INFO : dataset_reader.feature_labels = ()
# 2021-09-25 20:04:53,053 : INFO : dataset_reader.convert_to_coding_scheme = None
# 2021-09-25 20:04:53,053 : INFO : dataset_reader.label_namespace = labels
# 2021-09-25 20:04:53,054 : INFO : type = from_instances
# 2021-09-25 20:04:53,057 : INFO : Loading token dictionary from /tmp/tmpk6qw2vlh/vocabulary.
# 2021-09-25 20:04:53,083 : INFO : model.type = crf_tagger
# 2021-09-25 20:04:53,084 : INFO : model.regularizer.type = ref
# 2021-09-25 20:04:53,091 : INFO : type = scalar_parameters
# 2021-09-25 20:04:53,092 : INFO : model.regularizer.regexes.0.1.type = l2
# 2021-09-25 20:04:53,092 : INFO : model.regularizer.regexes.0.1.type = l2
# 2021-09-25 20:04:53,093 : INFO : model.regularizer.regexes.0.1.alpha = 0.1
# 2021-09-25 20:04:53,094 : INFO : model.ddp_accelerator = None
# 2021-09-25 20:04:53,096 : INFO : model.text_field_embedder.type = ref
# 2021-09-25 20:04:53,098 : INFO : model.text_field_embedder.type = basic
# 2021-09-25 20:04:53,100 : INFO : model.text_field_embedder.token_embedders.type = ref
# 2021-09-25 20:04:53,103 : INFO : model.text_field_embedder.token_embedders.elmo.type = elmo_token_embedder
# 2021-09-25 20:04:53,104 : INFO : model.text_field_embedder.token_embedders.elmo.type = elmo_token_embedder
# 2021-09-25 20:04:53,106 : INFO : model.text_field_embedder.token_embedders.elmo.options_file = https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_options.json
# 2021-09-25 20:04:53,116 : INFO : model.text_field_embedder.token_embedders.elmo.weight_file = https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5
# 2021-09-25 20:04:53,118 : INFO : model.text_field_embedder.token_embedders.elmo.do_layer_norm = False
# 2021-09-25 20:04:53,119 : INFO : model.text_field_embedder.token_embedders.elmo.dropout = 0
# 2021-09-25 20:04:53,121 : INFO : model.text_field_embedder.token_embedders.elmo.requires_grad = False
# 2021-09-25 20:04:53,122 : INFO : model.text_field_embedder.token_embedders.elmo.projection_dim = None
# 2021-09-25 20:04:53,125 : INFO : model.text_field_embedder.token_embedders.elmo.vocab_to_cache = None
# 2021-09-25 20:04:53,125 : INFO : model.text_field_embedder.token_embedders.elmo.scalar_mix_parameters = None
# 2021-09-25 20:04:53,126 : INFO : Initializing ELMo
# 2021-09-25 20:04:54,913 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_options.json is up-to-date
# 2021-09-25 20:04:56,018 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:04:57,145 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:04:58,276 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:04:59,406 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:00,526 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:01,651 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:02,779 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:03,905 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:05,237 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:06,363 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:07,591 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:08,819 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_options.json is up-to-date
# 2021-09-25 20:05:14,143 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:15,953 : INFO : model.text_field_embedder.token_embedders.token_characters.type = character_encoding
# 2021-09-25 20:05:15,953 : INFO : model.text_field_embedder.token_embedders.token_characters.type = character_encoding
# 2021-09-25 20:05:15,955 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.type = ref
# 2021-09-25 20:05:15,958 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.embedding_dim = 16
# 2021-09-25 20:05:15,959 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.num_embeddings = None
# 2021-09-25 20:05:15,960 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.projection_dim = None
# 2021-09-25 20:05:15,961 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.weight = None
# 2021-09-25 20:05:15,963 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.padding_index = None
# 2021-09-25 20:05:15,964 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.trainable = True
# 2021-09-25 20:05:15,968 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.max_norm = None
# 2021-09-25 20:05:15,982 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.norm_type = 2.0
# 2021-09-25 20:05:15,983 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.scale_grad_by_freq = False
# 2021-09-25 20:05:15,984 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.sparse = False
# 2021-09-25 20:05:15,986 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.vocab_namespace = token_characters
# 2021-09-25 20:05:15,987 : INFO : type = token_characters
# 2021-09-25 20:05:15,988 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.pretrained_file = None
# 2021-09-25 20:05:15,989 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.type = cnn
# 2021-09-25 20:05:15,990 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.type = cnn
# 2021-09-25 20:05:15,990 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.embedding_dim = 16
# 2021-09-25 20:05:15,991 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.num_filters = 128
# 2021-09-25 20:05:15,992 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.ngram_filter_sizes = [3]
# 2021-09-25 20:05:15,993 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.conv_layer_activation = relu
# 2021-09-25 20:05:15,994 : INFO : type = relu
# 2021-09-25 20:05:15,995 : INFO : type = relu
# 2021-09-25 20:05:15,996 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.output_dim = None
# 2021-09-25 20:05:15,997 : INFO : model.text_field_embedder.token_embedders.token_characters.dropout = 0.0
# 2021-09-25 20:05:16,002 : INFO : model.text_field_embedder.token_embedders.tokens.type = embedding
# 2021-09-25 20:05:16,004 : INFO : model.text_field_embedder.token_embedders.tokens.type = embedding
# 2021-09-25 20:05:16,005 : INFO : model.text_field_embedder.token_embedders.tokens.embedding_dim = 50
# 2021-09-25 20:05:16,007 : INFO : model.text_field_embedder.token_embedders.tokens.num_embeddings = None
# 2021-09-25 20:05:16,008 : INFO : model.text_field_embedder.token_embedders.tokens.projection_dim = None
# 2021-09-25 20:05:16,009 : INFO : model.text_field_embedder.token_embedders.tokens.weight = None
# 2021-09-25 20:05:16,010 : INFO : model.text_field_embedder.token_embedders.tokens.padding_index = None
# 2021-09-25 20:05:16,011 : INFO : model.text_field_embedder.token_embedders.tokens.trainable = True
# 2021-09-25 20:05:16,012 : INFO : model.text_field_embedder.token_embedders.tokens.max_norm = None
# 2021-09-25 20:05:16,013 : INFO : model.text_field_embedder.token_embedders.tokens.norm_type = 2.0
# 2021-09-25 20:05:16,014 : INFO : model.text_field_embedder.token_embedders.tokens.scale_grad_by_freq = False
# 2021-09-25 20:05:16,015 : INFO : model.text_field_embedder.token_embedders.tokens.sparse = False
# 2021-09-25 20:05:16,016 : INFO : model.text_field_embedder.token_embedders.tokens.vocab_namespace = tokens
# 2021-09-25 20:05:16,017 : INFO : model.text_field_embedder.token_embedders.tokens.pretrained_file = None
# 2021-09-25 20:05:16,036 : INFO : model.encoder.type = lstm
# 2021-09-25 20:05:16,040 : INFO : model.encoder.type = lstm
# 2021-09-25 20:05:16,042 : INFO : model.encoder.input_size = 1202
# 2021-09-25 20:05:16,043 : INFO : model.encoder.hidden_size = 200
# 2021-09-25 20:05:16,044 : INFO : model.encoder.num_layers = 2
# 2021-09-25 20:05:16,044 : INFO : model.encoder.bias = True
# 2021-09-25 20:05:16,045 : INFO : model.encoder.dropout = 0.5
# 2021-09-25 20:05:16,047 : INFO : model.encoder.bidirectional = True
# 2021-09-25 20:05:16,049 : INFO : model.encoder.stateful = False
# 2021-09-25 20:05:16,074 : INFO : model.label_namespace = labels
# 2021-09-25 20:05:16,075 : INFO : model.feedforward = None
# 2021-09-25 20:05:16,076 : INFO : model.label_encoding = BIOUL
# 2021-09-25 20:05:16,077 : INFO : type = BIOUL
# 2021-09-25 20:05:16,078 : INFO : model.include_start_end_transitions = False
# 2021-09-25 20:05:16,078 : INFO : model.constrain_crf_decoding = None
# 2021-09-25 20:05:16,079 : INFO : model.calculate_span_f1 = None
# 2021-09-25 20:05:16,080 : INFO : model.dropout = 0.5
# 2021-09-25 20:05:16,081 : INFO : model.verbose_metrics = False
# 2021-09-25 20:05:16,081 : INFO : model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7f63ac92a250>
# 2021-09-25 20:05:16,082 : INFO : model.top_k = 1
# 2021-09-25 20:05:16,082 : INFO : model.ignore_loss_on_o_tags = False
# 2021-09-25 20:05:16,094 : INFO : Initializing parameters
# 2021-09-25 20:05:16,097 : INFO : Done initializing parameters; the following parameters are using their default initialization from their code
# 2021-09-25 20:05:16,097 : INFO :    crf._constraint_mask
# 2021-09-25 20:05:16,098 : INFO :    crf.transitions
# 2021-09-25 20:05:16,099 : INFO :    encoder._module.bias_hh_l0
# 2021-09-25 20:05:16,100 : INFO :    encoder._module.bias_hh_l0_reverse
# 2021-09-25 20:05:16,101 : INFO :    encoder._module.bias_hh_l1
# 2021-09-25 20:05:16,101 : INFO :    encoder._module.bias_hh_l1_reverse
# 2021-09-25 20:05:16,102 : INFO :    encoder._module.bias_ih_l0
# 2021-09-25 20:05:16,103 : INFO :    encoder._module.bias_ih_l0_reverse
# 2021-09-25 20:05:16,103 : INFO :    encoder._module.bias_ih_l1
# 2021-09-25 20:05:16,104 : INFO :    encoder._module.bias_ih_l1_reverse
# 2021-09-25 20:05:16,108 : INFO :    encoder._module.weight_hh_l0
# 2021-09-25 20:05:16,112 : INFO :    encoder._module.weight_hh_l0_reverse
# 2021-09-25 20:05:16,113 : INFO :    encoder._module.weight_hh_l1
# 2021-09-25 20:05:16,114 : INFO :    encoder._module.weight_hh_l1_reverse
# 2021-09-25 20:05:16,114 : INFO :    encoder._module.weight_ih_l0
# 2021-09-25 20:05:16,115 : INFO :    encoder._module.weight_ih_l0_reverse
# 2021-09-25 20:05:16,116 : INFO :    encoder._module.weight_ih_l1
# 2021-09-25 20:05:16,117 : INFO :    encoder._module.weight_ih_l1_reverse
# 2021-09-25 20:05:16,117 : INFO :    tag_projection_layer._module.bias
# 2021-09-25 20:05:16,119 : INFO :    tag_projection_layer._module.weight
# 2021-09-25 20:05:16,121 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_0.input_linearity.weight
# 2021-09-25 20:05:16,123 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_0.state_linearity.bias
# 2021-09-25 20:05:16,124 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_0.state_linearity.weight
# 2021-09-25 20:05:16,125 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_0.state_projection.weight
# 2021-09-25 20:05:16,127 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_1.input_linearity.weight
# 2021-09-25 20:05:16,129 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_1.state_linearity.bias
# 2021-09-25 20:05:16,130 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_1.state_linearity.weight
# 2021-09-25 20:05:16,131 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_1.state_projection.weight
# 2021-09-25 20:05:16,132 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_0.input_linearity.weight
# 2021-09-25 20:05:16,132 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_0.state_linearity.bias
# 2021-09-25 20:05:16,133 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_0.state_linearity.weight
# 2021-09-25 20:05:16,134 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_0.state_projection.weight
# 2021-09-25 20:05:16,135 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_1.input_linearity.weight
# 2021-09-25 20:05:16,136 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_1.state_linearity.bias
# 2021-09-25 20:05:16,136 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_1.state_linearity.weight
# 2021-09-25 20:05:16,137 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_1.state_projection.weight
# 2021-09-25 20:05:16,141 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._char_embedding_weights
# 2021-09-25 20:05:16,142 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._highways._layers.0.bias
# 2021-09-25 20:05:16,147 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._highways._layers.0.weight
# 2021-09-25 20:05:16,148 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._highways._layers.1.bias
# 2021-09-25 20:05:16,148 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._highways._layers.1.weight
# 2021-09-25 20:05:16,149 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._projection.bias
# 2021-09-25 20:05:16,150 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._projection.weight
# 2021-09-25 20:05:16,151 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_0.bias
# 2021-09-25 20:05:16,152 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_0.weight
# 2021-09-25 20:05:16,154 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_1.bias
# 2021-09-25 20:05:16,154 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_1.weight
# 2021-09-25 20:05:16,157 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_2.bias
# 2021-09-25 20:05:16,158 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_2.weight
# 2021-09-25 20:05:16,159 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_3.bias
# 2021-09-25 20:05:16,160 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_3.weight
# 2021-09-25 20:05:16,164 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_4.bias
# 2021-09-25 20:05:16,165 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_4.weight
# 2021-09-25 20:05:16,166 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_5.bias
# 2021-09-25 20:05:16,167 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_5.weight
# 2021-09-25 20:05:16,168 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_6.bias
# 2021-09-25 20:05:16,169 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_6.weight
# 2021-09-25 20:05:16,169 : INFO :    text_field_embedder.token_embedder_elmo._elmo.scalar_mix_0.gamma
# 2021-09-25 20:05:16,170 : INFO :    text_field_embedder.token_embedder_elmo._elmo.scalar_mix_0.scalar_parameters.0
# 2021-09-25 20:05:16,171 : INFO :    text_field_embedder.token_embedder_elmo._elmo.scalar_mix_0.scalar_parameters.1
# 2021-09-25 20:05:16,175 : INFO :    text_field_embedder.token_embedder_elmo._elmo.scalar_mix_0.scalar_parameters.2
# 2021-09-25 20:05:16,176 : INFO :    text_field_embedder.token_embedder_token_characters._embedding._module.weight
# 2021-09-25 20:05:16,177 : INFO :    text_field_embedder.token_embedder_token_characters._encoder._module.conv_layer_0.bias
# 2021-09-25 20:05:16,181 : INFO :    text_field_embedder.token_embedder_token_characters._encoder._module.conv_layer_0.weight
# 2021-09-25 20:05:16,182 : INFO :    text_field_embedder.token_embedder_tokens.weight
# 2021-09-25 20:05:16,516 : INFO : removing temporary unarchived model dir at /tmp/tmpk6qw2vlh
# 2021-09-25 20:05:17,280 : INFO : Plugin allennlp_models available
# 2021-09-25 20:05:17,728 : INFO : cache of https://storage.googleapis.com/allennlp-public-models/fine-grained-ner.2021-02-11.tar.gz is up-to-date
# 2021-09-25 20:05:17,729 : INFO : loading archive file https://storage.googleapis.com/allennlp-public-models/fine-grained-ner.2021-02-11.tar.gz from cache at /home/dnk8n/.allennlp/cache/4ef068b228ad971c4c18a12c1020d91d6358cfc2a3ae723e14960c2a7a3cf8a8.47e5247f1fa5f9f3a76ba91d559b5dbf17403613e90ad37f76f90e2f231746b2
# 2021-09-25 20:05:17,730 : INFO : extracting archive file /home/dnk8n/.allennlp/cache/4ef068b228ad971c4c18a12c1020d91d6358cfc2a3ae723e14960c2a7a3cf8a8.47e5247f1fa5f9f3a76ba91d559b5dbf17403613e90ad37f76f90e2f231746b2 to temp dir /tmp/tmpyfitun9f
# 2021-09-25 20:05:20,696 : INFO : dataset_reader.type = ontonotes_ner
# 2021-09-25 20:05:20,697 : INFO : dataset_reader.max_instances = None
# 2021-09-25 20:05:20,697 : INFO : dataset_reader.manual_distributed_sharding = False
# 2021-09-25 20:05:20,699 : INFO : dataset_reader.manual_multiprocess_sharding = False
# 2021-09-25 20:05:20,700 : INFO : dataset_reader.token_indexers.type = ref
# 2021-09-25 20:05:20,703 : INFO : dataset_reader.token_indexers.elmo.type = elmo_characters
# 2021-09-25 20:05:20,705 : INFO : dataset_reader.token_indexers.elmo.type = elmo_characters
# 2021-09-25 20:05:20,706 : INFO : dataset_reader.token_indexers.elmo.namespace = elmo_characters
# 2021-09-25 20:05:20,712 : INFO : dataset_reader.token_indexers.elmo.tokens_to_add = None
# 2021-09-25 20:05:20,713 : INFO : dataset_reader.token_indexers.elmo.token_min_padding_length = 0
# 2021-09-25 20:05:20,715 : INFO : dataset_reader.token_indexers.token_characters.type = characters
# 2021-09-25 20:05:20,716 : INFO : dataset_reader.token_indexers.token_characters.type = characters
# 2021-09-25 20:05:20,717 : INFO : dataset_reader.token_indexers.token_characters.namespace = token_characters
# 2021-09-25 20:05:20,718 : INFO : dataset_reader.token_indexers.token_characters.character_tokenizer = <allennlp.data.tokenizers.character_tokenizer.CharacterTokenizer object at 0x7f63ca44e760>
# 2021-09-25 20:05:20,719 : INFO : dataset_reader.token_indexers.token_characters.start_tokens = None
# 2021-09-25 20:05:20,723 : INFO : dataset_reader.token_indexers.token_characters.end_tokens = None
# 2021-09-25 20:05:20,726 : INFO : dataset_reader.token_indexers.token_characters.min_padding_length = 0
# 2021-09-25 20:05:20,727 : INFO : dataset_reader.token_indexers.token_characters.token_min_padding_length = 0
# 2021-09-25 20:05:20,729 : INFO : dataset_reader.token_indexers.tokens.type = single_id
# 2021-09-25 20:05:20,730 : INFO : dataset_reader.token_indexers.tokens.type = single_id
# 2021-09-25 20:05:20,731 : INFO : dataset_reader.token_indexers.tokens.namespace = tokens
# 2021-09-25 20:05:20,732 : INFO : dataset_reader.token_indexers.tokens.lowercase_tokens = True
# 2021-09-25 20:05:20,734 : INFO : dataset_reader.token_indexers.tokens.start_tokens = None
# 2021-09-25 20:05:20,735 : INFO : dataset_reader.token_indexers.tokens.end_tokens = None
# 2021-09-25 20:05:20,736 : INFO : dataset_reader.token_indexers.tokens.feature_name = text
# 2021-09-25 20:05:20,737 : INFO : dataset_reader.token_indexers.tokens.default_value = THIS IS A REALLY UNLIKELY VALUE THAT HAS TO BE A STRING
# 2021-09-25 20:05:20,742 : INFO : dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2021-09-25 20:05:20,744 : INFO : dataset_reader.domain_identifier = None
# 2021-09-25 20:05:20,745 : INFO : dataset_reader.coding_scheme = BIOUL
# 2021-09-25 20:05:20,746 : INFO : type = BIOUL
# 2021-09-25 20:05:20,747 : INFO : dataset_reader.type = ontonotes_ner
# 2021-09-25 20:05:20,749 : INFO : dataset_reader.max_instances = None
# 2021-09-25 20:05:20,749 : INFO : dataset_reader.manual_distributed_sharding = False
# 2021-09-25 20:05:20,750 : INFO : dataset_reader.manual_multiprocess_sharding = False
# 2021-09-25 20:05:20,751 : INFO : dataset_reader.token_indexers.type = ref
# 2021-09-25 20:05:20,755 : INFO : dataset_reader.token_indexers.elmo.type = elmo_characters
# 2021-09-25 20:05:20,759 : INFO : dataset_reader.token_indexers.elmo.type = elmo_characters
# 2021-09-25 20:05:20,760 : INFO : dataset_reader.token_indexers.elmo.namespace = elmo_characters
# 2021-09-25 20:05:20,761 : INFO : dataset_reader.token_indexers.elmo.tokens_to_add = None
# 2021-09-25 20:05:20,762 : INFO : dataset_reader.token_indexers.elmo.token_min_padding_length = 0
# 2021-09-25 20:05:20,763 : INFO : dataset_reader.token_indexers.token_characters.type = characters
# 2021-09-25 20:05:20,767 : INFO : dataset_reader.token_indexers.token_characters.type = characters
# 2021-09-25 20:05:20,768 : INFO : dataset_reader.token_indexers.token_characters.namespace = token_characters
# 2021-09-25 20:05:20,769 : INFO : dataset_reader.token_indexers.token_characters.character_tokenizer = <allennlp.data.tokenizers.character_tokenizer.CharacterTokenizer object at 0x7f63ca44e760>
# 2021-09-25 20:05:20,770 : INFO : dataset_reader.token_indexers.token_characters.start_tokens = None
# 2021-09-25 20:05:20,775 : INFO : dataset_reader.token_indexers.token_characters.end_tokens = None
# 2021-09-25 20:05:20,776 : INFO : dataset_reader.token_indexers.token_characters.min_padding_length = 0
# 2021-09-25 20:05:20,778 : INFO : dataset_reader.token_indexers.token_characters.token_min_padding_length = 0
# 2021-09-25 20:05:20,780 : INFO : dataset_reader.token_indexers.tokens.type = single_id
# 2021-09-25 20:05:20,781 : INFO : dataset_reader.token_indexers.tokens.type = single_id
# 2021-09-25 20:05:20,782 : INFO : dataset_reader.token_indexers.tokens.namespace = tokens
# 2021-09-25 20:05:20,783 : INFO : dataset_reader.token_indexers.tokens.lowercase_tokens = True
# 2021-09-25 20:05:20,784 : INFO : dataset_reader.token_indexers.tokens.start_tokens = None
# 2021-09-25 20:05:20,784 : INFO : dataset_reader.token_indexers.tokens.end_tokens = None
# 2021-09-25 20:05:20,785 : INFO : dataset_reader.token_indexers.tokens.feature_name = text
# 2021-09-25 20:05:20,786 : INFO : dataset_reader.token_indexers.tokens.default_value = THIS IS A REALLY UNLIKELY VALUE THAT HAS TO BE A STRING
# 2021-09-25 20:05:20,787 : INFO : dataset_reader.token_indexers.tokens.token_min_padding_length = 0
# 2021-09-25 20:05:20,790 : INFO : dataset_reader.domain_identifier = None
# 2021-09-25 20:05:20,792 : INFO : dataset_reader.coding_scheme = BIOUL
# 2021-09-25 20:05:20,793 : INFO : type = BIOUL
# 2021-09-25 20:05:20,794 : INFO : type = from_instances
# 2021-09-25 20:05:20,794 : INFO : Loading token dictionary from /tmp/tmpyfitun9f/vocabulary.
# 2021-09-25 20:05:20,857 : INFO : model.type = crf_tagger
# 2021-09-25 20:05:20,858 : INFO : model.regularizer.type = ref
# 2021-09-25 20:05:20,861 : INFO : type = scalar_parameters
# 2021-09-25 20:05:20,862 : INFO : model.regularizer.regexes.0.1.type = l2
# 2021-09-25 20:05:20,863 : INFO : model.regularizer.regexes.0.1.type = l2
# 2021-09-25 20:05:20,863 : INFO : model.regularizer.regexes.0.1.alpha = 0.001
# 2021-09-25 20:05:20,864 : INFO : model.ddp_accelerator = None
# 2021-09-25 20:05:20,865 : INFO : model.text_field_embedder.type = ref
# 2021-09-25 20:05:20,868 : INFO : model.text_field_embedder.type = basic
# 2021-09-25 20:05:20,872 : INFO : model.text_field_embedder.token_embedders.type = ref
# 2021-09-25 20:05:20,876 : INFO : model.text_field_embedder.token_embedders.elmo.type = elmo_token_embedder
# 2021-09-25 20:05:20,878 : INFO : model.text_field_embedder.token_embedders.elmo.type = elmo_token_embedder
# 2021-09-25 20:05:20,879 : INFO : model.text_field_embedder.token_embedders.elmo.options_file = https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_options.json
# 2021-09-25 20:05:20,883 : INFO : model.text_field_embedder.token_embedders.elmo.weight_file = https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5
# 2021-09-25 20:05:20,883 : INFO : model.text_field_embedder.token_embedders.elmo.do_layer_norm = False
# 2021-09-25 20:05:20,884 : INFO : model.text_field_embedder.token_embedders.elmo.dropout = 0
# 2021-09-25 20:05:20,885 : INFO : model.text_field_embedder.token_embedders.elmo.requires_grad = False
# 2021-09-25 20:05:20,886 : INFO : model.text_field_embedder.token_embedders.elmo.projection_dim = None
# 2021-09-25 20:05:20,887 : INFO : model.text_field_embedder.token_embedders.elmo.vocab_to_cache = None
# 2021-09-25 20:05:20,889 : INFO : model.text_field_embedder.token_embedders.elmo.scalar_mix_parameters = None
# 2021-09-25 20:05:20,890 : INFO : Initializing ELMo
# 2021-09-25 20:05:22,028 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_options.json is up-to-date
# 2021-09-25 20:05:23,157 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:24,234 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:25,228 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:26,433 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:27,557 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:28,684 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:29,811 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:30,938 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:32,165 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:33,394 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:34,521 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:35,648 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_options.json is up-to-date
# 2021-09-25 20:05:40,972 : INFO : cache of https://allennlp.s3.amazonaws.com/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5 is up-to-date
# 2021-09-25 20:05:42,711 : INFO : model.text_field_embedder.token_embedders.token_characters.type = character_encoding
# 2021-09-25 20:05:42,712 : INFO : model.text_field_embedder.token_embedders.token_characters.type = character_encoding
# 2021-09-25 20:05:42,713 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.type = ref
# 2021-09-25 20:05:42,716 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.embedding_dim = 25
# 2021-09-25 20:05:42,717 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.num_embeddings = None
# 2021-09-25 20:05:42,717 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.projection_dim = None
# 2021-09-25 20:05:42,718 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.weight = None
# 2021-09-25 20:05:42,719 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.padding_index = None
# 2021-09-25 20:05:42,720 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.trainable = True
# 2021-09-25 20:05:42,721 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.max_norm = None
# 2021-09-25 20:05:42,722 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.norm_type = 2.0
# 2021-09-25 20:05:42,727 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.scale_grad_by_freq = False
# 2021-09-25 20:05:42,728 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.sparse = True
# 2021-09-25 20:05:42,730 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.vocab_namespace = token_characters
# 2021-09-25 20:05:42,731 : INFO : type = token_characters
# 2021-09-25 20:05:42,732 : INFO : model.text_field_embedder.token_embedders.token_characters.embedding.pretrained_file = None
# 2021-09-25 20:05:42,733 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.type = lstm
# 2021-09-25 20:05:42,734 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.type = lstm
# 2021-09-25 20:05:42,736 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.input_size = 25
# 2021-09-25 20:05:42,739 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.hidden_size = 128
# 2021-09-25 20:05:42,742 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.num_layers = 1
# 2021-09-25 20:05:42,743 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.bias = True
# 2021-09-25 20:05:42,744 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.dropout = 0.0
# 2021-09-25 20:05:42,745 : INFO : model.text_field_embedder.token_embedders.token_characters.encoder.bidirectional = False
# 2021-09-25 20:05:42,747 : INFO : model.text_field_embedder.token_embedders.token_characters.dropout = 0.0
# 2021-09-25 20:05:42,748 : INFO : model.text_field_embedder.token_embedders.tokens.type = embedding
# 2021-09-25 20:05:42,749 : INFO : model.text_field_embedder.token_embedders.tokens.type = embedding
# 2021-09-25 20:05:42,750 : INFO : model.text_field_embedder.token_embedders.tokens.embedding_dim = 50
# 2021-09-25 20:05:42,753 : INFO : model.text_field_embedder.token_embedders.tokens.num_embeddings = None
# 2021-09-25 20:05:42,753 : INFO : model.text_field_embedder.token_embedders.tokens.projection_dim = None
# 2021-09-25 20:05:42,755 : INFO : model.text_field_embedder.token_embedders.tokens.weight = None
# 2021-09-25 20:05:42,756 : INFO : model.text_field_embedder.token_embedders.tokens.padding_index = None
# 2021-09-25 20:05:42,757 : INFO : model.text_field_embedder.token_embedders.tokens.trainable = True
# 2021-09-25 20:05:42,758 : INFO : model.text_field_embedder.token_embedders.tokens.max_norm = None
# 2021-09-25 20:05:42,758 : INFO : model.text_field_embedder.token_embedders.tokens.norm_type = 2.0
# 2021-09-25 20:05:42,760 : INFO : model.text_field_embedder.token_embedders.tokens.scale_grad_by_freq = False
# 2021-09-25 20:05:42,760 : INFO : model.text_field_embedder.token_embedders.tokens.sparse = True
# 2021-09-25 20:05:42,761 : INFO : model.text_field_embedder.token_embedders.tokens.vocab_namespace = tokens
# 2021-09-25 20:05:42,771 : INFO : model.text_field_embedder.token_embedders.tokens.pretrained_file = None
# 2021-09-25 20:05:42,797 : INFO : model.encoder.type = stacked_bidirectional_lstm
# 2021-09-25 20:05:42,798 : INFO : model.encoder.type = stacked_bidirectional_lstm
# 2021-09-25 20:05:42,799 : INFO : model.encoder.input_size = 1202
# 2021-09-25 20:05:42,801 : INFO : model.encoder.hidden_size = 200
# 2021-09-25 20:05:42,802 : INFO : model.encoder.num_layers = 2
# 2021-09-25 20:05:42,803 : INFO : model.encoder.recurrent_dropout_probability = 0.5
# 2021-09-25 20:05:42,805 : INFO : model.encoder.layer_dropout_probability = 0.0
# 2021-09-25 20:05:42,806 : INFO : model.encoder.use_highway = True
# 2021-09-25 20:05:42,807 : INFO : model.encoder.stateful = False
# 2021-09-25 20:05:42,970 : INFO : model.label_namespace = labels
# 2021-09-25 20:05:42,971 : INFO : model.feedforward.type = ref
# 2021-09-25 20:05:42,973 : INFO : model.feedforward.input_dim = 400
# 2021-09-25 20:05:42,975 : INFO : model.feedforward.num_layers = 1
# 2021-09-25 20:05:42,976 : INFO : model.feedforward.hidden_dims = 400
# 2021-09-25 20:05:42,979 : INFO : model.feedforward.activations = tanh
# 2021-09-25 20:05:42,980 : INFO : type = tanh
# 2021-09-25 20:05:42,982 : INFO : type = tanh
# 2021-09-25 20:05:42,983 : INFO : type = tanh
# 2021-09-25 20:05:42,984 : INFO : model.feedforward.dropout = 0.5
# 2021-09-25 20:05:42,987 : INFO : model.label_encoding = BIOUL
# 2021-09-25 20:05:42,989 : INFO : type = BIOUL
# 2021-09-25 20:05:42,990 : INFO : model.include_start_end_transitions = False
# 2021-09-25 20:05:42,991 : INFO : model.constrain_crf_decoding = None
# 2021-09-25 20:05:42,992 : INFO : model.calculate_span_f1 = None
# 2021-09-25 20:05:42,993 : INFO : model.dropout = 0.5
# 2021-09-25 20:05:42,994 : INFO : model.verbose_metrics = True
# 2021-09-25 20:05:42,996 : INFO : model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7f63ac92a250>
# 2021-09-25 20:05:42,997 : INFO : model.top_k = 1
# 2021-09-25 20:05:42,999 : INFO : model.ignore_loss_on_o_tags = False
# 2021-09-25 20:05:43,015 : INFO : Initializing parameters
# 2021-09-25 20:05:43,016 : INFO : Done initializing parameters; the following parameters are using their default initialization from their code
# 2021-09-25 20:05:43,017 : INFO :    _feedforward._linear_layers.0.bias
# 2021-09-25 20:05:43,017 : INFO :    _feedforward._linear_layers.0.weight
# 2021-09-25 20:05:43,018 : INFO :    crf._constraint_mask
# 2021-09-25 20:05:43,019 : INFO :    crf.transitions
# 2021-09-25 20:05:43,022 : INFO :    encoder._module.backward_layer_0.cell.input_linearity.weight
# 2021-09-25 20:05:43,023 : INFO :    encoder._module.backward_layer_0.cell.state_linearity.bias
# 2021-09-25 20:05:43,024 : INFO :    encoder._module.backward_layer_0.cell.state_linearity.weight
# 2021-09-25 20:05:43,025 : INFO :    encoder._module.backward_layer_1.cell.input_linearity.weight
# 2021-09-25 20:05:43,026 : INFO :    encoder._module.backward_layer_1.cell.state_linearity.bias
# 2021-09-25 20:05:43,026 : INFO :    encoder._module.backward_layer_1.cell.state_linearity.weight
# 2021-09-25 20:05:43,027 : INFO :    encoder._module.forward_layer_0.cell.input_linearity.weight
# 2021-09-25 20:05:43,028 : INFO :    encoder._module.forward_layer_0.cell.state_linearity.bias
# 2021-09-25 20:05:43,029 : INFO :    encoder._module.forward_layer_0.cell.state_linearity.weight
# 2021-09-25 20:05:43,029 : INFO :    encoder._module.forward_layer_1.cell.input_linearity.weight
# 2021-09-25 20:05:43,030 : INFO :    encoder._module.forward_layer_1.cell.state_linearity.bias
# 2021-09-25 20:05:43,035 : INFO :    encoder._module.forward_layer_1.cell.state_linearity.weight
# 2021-09-25 20:05:43,036 : INFO :    tag_projection_layer._module.bias
# 2021-09-25 20:05:43,037 : INFO :    tag_projection_layer._module.weight
# 2021-09-25 20:05:43,038 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_0.input_linearity.weight
# 2021-09-25 20:05:43,039 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_0.state_linearity.bias
# 2021-09-25 20:05:43,040 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_0.state_linearity.weight
# 2021-09-25 20:05:43,041 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_0.state_projection.weight
# 2021-09-25 20:05:43,043 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_1.input_linearity.weight
# 2021-09-25 20:05:43,044 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_1.state_linearity.bias
# 2021-09-25 20:05:43,044 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_1.state_linearity.weight
# 2021-09-25 20:05:43,045 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.backward_layer_1.state_projection.weight
# 2021-09-25 20:05:43,045 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_0.input_linearity.weight
# 2021-09-25 20:05:43,046 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_0.state_linearity.bias
# 2021-09-25 20:05:43,047 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_0.state_linearity.weight
# 2021-09-25 20:05:43,047 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_0.state_projection.weight
# 2021-09-25 20:05:43,048 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_1.input_linearity.weight
# 2021-09-25 20:05:43,050 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_1.state_linearity.bias
# 2021-09-25 20:05:43,052 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_1.state_linearity.weight
# 2021-09-25 20:05:43,053 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._elmo_lstm.forward_layer_1.state_projection.weight
# 2021-09-25 20:05:43,055 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._char_embedding_weights
# 2021-09-25 20:05:43,056 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._highways._layers.0.bias
# 2021-09-25 20:05:43,056 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._highways._layers.0.weight
# 2021-09-25 20:05:43,057 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._highways._layers.1.bias
# 2021-09-25 20:05:43,058 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._highways._layers.1.weight
# 2021-09-25 20:05:43,059 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._projection.bias
# 2021-09-25 20:05:43,060 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder._projection.weight
# 2021-09-25 20:05:43,061 : INFO :    text_field_embedder.token_embedder_elmo._elmo._elmo_lstm._token_embedder.char_conv_0.bias
# ...
# 2021-09-25 20:06:02,943 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.3.output.LayerNorm.weight
# 2021-09-25 20:06:02,943 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.3.output.dense.bias
# 2021-09-25 20:06:02,944 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.3.output.dense.weight
# 2021-09-25 20:06:02,945 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.attention.output.LayerNorm.bias
# 2021-09-25 20:06:02,945 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.attention.output.LayerNorm.weight
# 2021-09-25 20:06:02,946 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.attention.output.dense.bias
# 2021-09-25 20:06:02,947 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.attention.output.dense.weight
# 2021-09-25 20:06:02,952 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.attention.self.key.bias
# 2021-09-25 20:06:02,953 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.attention.self.key.weight
# 2021-09-25 20:06:02,954 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.attention.self.query.bias
# 2021-09-25 20:06:02,956 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.attention.self.query.weight
# 2021-09-25 20:06:02,956 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.attention.self.value.bias
# 2021-09-25 20:06:02,957 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.attention.self.value.weight
# 2021-09-25 20:06:02,958 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.intermediate.dense.bias
# 2021-09-25 20:06:02,959 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.intermediate.dense.weight
# 2021-09-25 20:06:02,960 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.output.LayerNorm.bias
# 2021-09-25 20:06:02,961 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.output.LayerNorm.weight
# 2021-09-25 20:06:02,962 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.output.dense.bias
# 2021-09-25 20:06:02,962 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.4.output.dense.weight
# 2021-09-25 20:06:02,963 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.LayerNorm.bias
# 2021-09-25 20:06:02,966 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.LayerNorm.weight
# 2021-09-25 20:06:02,969 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.bias
# 2021-09-25 20:06:02,969 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.output.dense.weight
# 2021-09-25 20:06:02,970 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.bias
# 2021-09-25 20:06:02,973 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.key.weight
# 2021-09-25 20:06:02,973 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.bias
# 2021-09-25 20:06:02,974 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.query.weight
# 2021-09-25 20:06:02,975 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.bias
# 2021-09-25 20:06:02,976 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.attention.self.value.weight
# 2021-09-25 20:06:02,977 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.bias
# 2021-09-25 20:06:02,977 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.intermediate.dense.weight
# 2021-09-25 20:06:02,978 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.bias
# 2021-09-25 20:06:02,978 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.LayerNorm.weight
# 2021-09-25 20:06:02,979 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.dense.bias
# 2021-09-25 20:06:02,980 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.5.output.dense.weight
# 2021-09-25 20:06:02,980 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.bias
# 2021-09-25 20:06:02,984 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.LayerNorm.weight
# 2021-09-25 20:06:02,985 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.bias
# 2021-09-25 20:06:02,986 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.output.dense.weight
# 2021-09-25 20:06:02,988 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.bias
# 2021-09-25 20:06:02,989 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.key.weight
# 2021-09-25 20:06:02,990 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.bias
# 2021-09-25 20:06:02,991 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.query.weight
# 2021-09-25 20:06:02,992 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.bias
# 2021-09-25 20:06:02,993 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.attention.self.value.weight
# 2021-09-25 20:06:02,993 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.bias
# 2021-09-25 20:06:02,994 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.intermediate.dense.weight
# 2021-09-25 20:06:02,995 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.bias
# 2021-09-25 20:06:02,996 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.LayerNorm.weight
# 2021-09-25 20:06:02,997 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.bias
# 2021-09-25 20:06:02,997 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.6.output.dense.weight
# 2021-09-25 20:06:02,998 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.bias
# 2021-09-25 20:06:03,002 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.LayerNorm.weight
# 2021-09-25 20:06:03,003 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.bias
# 2021-09-25 20:06:03,005 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.output.dense.weight
# 2021-09-25 20:06:03,006 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.bias
# 2021-09-25 20:06:03,007 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.key.weight
# 2021-09-25 20:06:03,008 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.bias
# 2021-09-25 20:06:03,008 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.query.weight
# 2021-09-25 20:06:03,009 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.bias
# 2021-09-25 20:06:03,013 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.attention.self.value.weight
# 2021-09-25 20:06:03,015 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.bias
# 2021-09-25 20:06:03,018 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.intermediate.dense.weight
# 2021-09-25 20:06:03,019 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.bias
# 2021-09-25 20:06:03,021 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.LayerNorm.weight
# 2021-09-25 20:06:03,022 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.bias
# 2021-09-25 20:06:03,023 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.7.output.dense.weight
# 2021-09-25 20:06:03,024 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2021-09-25 20:06:03,024 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2021-09-25 20:06:03,025 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.bias
# 2021-09-25 20:06:03,026 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.output.dense.weight
# 2021-09-25 20:06:03,028 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.bias
# 2021-09-25 20:06:03,029 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.key.weight
# 2021-09-25 20:06:03,029 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.bias
# 2021-09-25 20:06:03,030 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.query.weight
# 2021-09-25 20:06:03,032 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.bias
# 2021-09-25 20:06:03,035 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.attention.self.value.weight
# 2021-09-25 20:06:03,039 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.bias
# 2021-09-25 20:06:03,040 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.intermediate.dense.weight
# 2021-09-25 20:06:03,041 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.bias
# 2021-09-25 20:06:03,042 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.LayerNorm.weight
# 2021-09-25 20:06:03,042 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.bias
# 2021-09-25 20:06:03,043 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.8.output.dense.weight
# 2021-09-25 20:06:03,044 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2021-09-25 20:06:03,045 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2021-09-25 20:06:03,046 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.bias
# 2021-09-25 20:06:03,047 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.output.dense.weight
# 2021-09-25 20:06:03,049 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.bias
# 2021-09-25 20:06:03,052 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.key.weight
# 2021-09-25 20:06:03,052 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.bias
# 2021-09-25 20:06:03,055 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.query.weight
# 2021-09-25 20:06:03,056 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.bias
# 2021-09-25 20:06:03,057 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.attention.self.value.weight
# 2021-09-25 20:06:03,058 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.bias
# 2021-09-25 20:06:03,059 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.intermediate.dense.weight
# 2021-09-25 20:06:03,060 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.bias
# 2021-09-25 20:06:03,061 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.LayerNorm.weight
# 2021-09-25 20:06:03,062 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.bias
# 2021-09-25 20:06:03,063 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.encoder.layer.9.output.dense.weight
# 2021-09-25 20:06:03,067 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.bias
# 2021-09-25 20:06:03,068 : INFO :    text_field_embedder.token_embedder_tokens._matched_embedder.transformer_model.pooler.dense.weight
# 2021-09-25 20:06:03,526 : INFO : removing temporary unarchived model dir at /tmp/tmps4py1d98
# CPU times: user 40.1 s, sys: 3.85 s, total: 43.9 s
# Wall time: 1min 22s

# %%
def get_ents(predictor, doc):
    prediction = predictor.predict(sentence=doc)
    return list(zip(prediction['words'], prediction['tags']))

# %%
# %%time

from collections import defaultdict

unmerged_ents = defaultdict(list)
for model, predictor in predictors.items():
    for doc in corpus_texts_full[:2]:
        unmerged_ents[model].append(get_ents(predictor, doc))
# Out:
# /home/dnk8n/miniconda3/envs/internship/lib/python3.8/site-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# CPU times: user 7min 13s, sys: 3.99 s, total: 7min 17s
# Wall time: 3min 41s

# %%
import itertools

def get_merged_ents(ents):
    all_ents = []
    for ents_doc in ents:
        ents_ids = get_ents_ids(ents_doc)
        doc_ents = []
        for ent_ids in ents_ids:
            word_tag_ents = []
            for ent_id in ent_ids:
                word_ent, tag_ent = ents_doc[ent_id]
                word_tag_ent = (
                    word_ent.split("'")[0], # This drops any 'll 'm 's that might be part of the ent
                    tag_ent.split("-")[1], # This drops the U- B- I- from ent types
                )
                word_tag_ents.append(word_tag_ent)
            ent_words, ent_tags = list(zip(*word_tag_ents))
            combined_ent_words = ' '.join(ent_words)
            collapsed_ent_tags = ' '.join(i for i, _ in itertools.groupby(ent_tags))
            doc_ents.append((combined_ent_words, collapsed_ent_tags))
        all_ents.append(doc_ents)
    return all_ents

# %%
# %%time
merged_ents = {}
for model, ents in unmerged_ents.items():
    merged_ents[model] = get_merged_ents(ents)
# Out:
# CPU times: user 42 ms, sys: 1.94 ms, total: 43.9 ms
# Wall time: 41.8 ms

# %%
import re

specifier = re.split('[\/\.]',csv_file_path)[-2]
json_save(merged_ents, f'merged_ents-{specifier}.json')
